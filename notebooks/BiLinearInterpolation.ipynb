# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
path = './cat1.jpg'
H = 400
W = 400

# %%
img = np.array(Image.open(path).resize((H, W)))
print(img.shape)
# Out:
# (400, 400, 3)
